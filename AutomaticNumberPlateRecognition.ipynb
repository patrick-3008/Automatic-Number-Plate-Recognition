# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16066457650642566598
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 4162846720
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 5503162718130425585
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1660 SUPER, pci bus id: 0000:07:00.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]

# %%
# Getting dataset
from roboflow import Roboflow
rf = Roboflow(api_key="JacL3NDrrfMYJhpFHpJB")
project = rf.workspace("matheus-santos-almeida").project("car_license_plate")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.20, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to car_license_plate-1 in yolov8:: 100%|██████████| 612/612 [00:00<00:00, 2182.79it/s]

# %%
from ultralytics import YOLO

# # Load a model
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# # Train the model with 2 GPUs
dataset='C:/Users/Patrickn/Jupyter_notebooks/Automatic-Number-Plate-Recognition/dataset/data.yaml'
results = model.train(data=dataset, epochs=200, imgsz=640, device=0)
# Out:
# yolo\engine\trainer: task=detect, mode=train, model=yolov8n.yaml, data=C:/Users/Patrickn/Jupyter_notebooks/Automatic-Number-Plate-Recognition/dataset/data.yaml, epochs=200, patience=50, batch=16, imgsz=640, save=True, cache=False, device=0, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=False, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=True, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, retina_masks=False, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('C:/Users/Patrickn/Jupyter_notebooks/Automatic-Number-Plate-Recognition/runs/detect/train/weights/best.pt')

# Run inference on 'bus.jpg' with arguments
testPath='C:/Users/Patrickn/Jupyter_notebooks/Automatic-Number-Plate-Recognition/dataset/test/images/Cars54_png.rf.cb6867c72116a0b5e843d70cbe18c480.jpg'
model.predict(testPath, save=True, imgsz=320, conf=0.2)
# Out:
# WARNING  Ultralytics settings reset to defaults.
# This is normal and may be due to a recent ultralytics package update, but may have overwritten previous settings.
# You may view and update settings directly in 'C:\Users\Patrickn\AppData\Roaming\Ultralytics\settings.yaml'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from ultralytics import YOLO
#       3 # Load a pretrained YOLOv8n model
# ----> 4 model = YOLO('ultralytics/runs/detect/train_model/weights/best.pt')
#       6 # Run inference on 'bus.jpg' with arguments
#       7 testPath='C:/Users/Patrickn/Jupyter_notebooks/Automatic-Number-Plate-Recognition/dataset/test/images/Cars54_png.rf.cb6867c72116a0b5e843d70cbe18c480.jpg'
#
# File c:\Users\Patrickn\.conda\envs\tf_gpu\lib\site-packages\ultralytics\yolo\engine\model.py:60, in YOLO.__init__(self, model, type)
# ...
