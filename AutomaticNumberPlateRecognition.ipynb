# %% [markdown]
# 0. Install and Import Dependencies

# %%
# !pip install easyocr
# !pip install imutils
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting easyocr
#   Using cached easyocr-1.7.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: torch in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from easyocr) (2.3.1+cu121)
# Requirement already satisfied: torchvision>=0.5 in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from easyocr) (0.18.1+cu121)
# Collecting opencv-python-headless (from easyocr)
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from easyocr) (1.13.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from easyocr) (1.26.4)
# Requirement already satisfied: Pillow in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from easyocr) (10.3.0)
# Requirement already satisfied: scikit-image in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from easyocr) (0.24.0)
# Collecting python-bidi (from easyocr)
#   Using cached python_bidi-0.4.2-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: PyYAML in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from easyocr) (6.0.1)
# Collecting Shapely (from easyocr)
#   Downloading shapely-2.0.4-cp39-cp39-win_amd64.whl.metadata (7.2 kB)
# Collecting pyclipper (from easyocr)
#   Downloading pyclipper-1.3.0.post5-cp39-cp39-win_amd64.whl.metadata (9.2 kB)
# Collecting ninja (from easyocr)
#   Using cached ninja-1.11.1.1-py2.py3-none-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from torch->easyocr) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from torch->easyocr) (4.12.2)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from torch->easyocr) (1.12.1)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from torch->easyocr) (3.2.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from torch->easyocr) (3.1.4)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from torch->easyocr) (2024.6.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from torch->easyocr) (2021.4.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.33 in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from scikit-image->easyocr) (2.34.2)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from scikit-image->easyocr) (2024.6.18)
# Requirement already satisfied: packaging>=21 in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from scikit-image->easyocr) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: intel-openmp==2021.* in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->easyocr) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->easyocr) (2021.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from jinja2->torch->easyocr) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\programdata\anaconda3\envs\pytorch_gpu\lib\site-packages (from sympy->torch->easyocr) (1.3.0)
# Using cached easyocr-1.7.1-py3-none-any.whl (2.9 MB)
# Using cached ninja-1.11.1.1-py2.py3-none-win_amd64.whl (312 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Downloading pyclipper-1.3.0.post5-cp39-cp39-win_amd64.whl (108 kB)
#    ---------------------------------------- 0.0/108.6 kB ? eta -:--:--
#    ----------- --------------------------- 30.7/108.6 kB 660.6 kB/s eta 0:00:01
#    ---------------------- ---------------- 61.4/108.6 kB 825.8 kB/s eta 0:00:01
#    -------------------------------------- 108.6/108.6 kB 902.5 kB/s eta 0:00:00
# Using cached python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Downloading shapely-2.0.4-cp39-cp39-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    - -------------------------------------- 0.1/1.4 MB 1.6 MB/s eta 0:00:01
#    --- ------------------------------------ 0.1/1.4 MB 1.6 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.2/1.4 MB 1.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.2/1.4 MB 1.5 MB/s eta 0:00:01
#    ------ --------------------------------- 0.2/1.4 MB 1.1 MB/s eta 0:00:02
#    -------- ------------------------------- 0.3/1.4 MB 1.3 MB/s eta 0:00:01
#    --------- ------------------------------ 0.3/1.4 MB 1.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.4/1.4 MB 1.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.4/1.4 MB 1.1 MB/s eta 0:00:01
#    ------------ --------------------------- 0.5/1.4 MB 1.2 MB/s eta 0:00:01
#    ------------- -------------------------- 0.5/1.4 MB 1.1 MB/s eta 0:00:01
#    -------------- ------------------------- 0.5/1.4 MB 1.1 MB/s eta 0:00:01
#    --------------- ------------------------ 0.6/1.4 MB 1.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.6/1.4 MB 1.1 MB/s eta 0:00:01
#    ------------------ --------------------- 0.7/1.4 MB 1.1 MB/s eta 0:00:01
#    ------------------- -------------------- 0.7/1.4 MB 1.1 MB/s eta 0:00:01
#    --------------------- ------------------ 0.8/1.4 MB 1.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.8/1.4 MB 1.1 MB/s eta 0:00:01
#    ------------------------ --------------- 0.9/1.4 MB 1.1 MB/s eta 0:00:01
#    ------------------------ --------------- 0.9/1.4 MB 1.2 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.4 MB 1.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.4 MB 1.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.4 MB 1.1 MB/s eta 0:00:01
#    ------------------------------ --------- 1.1/1.4 MB 1.1 MB/s eta 0:00:01
#    ------------------------------ --------- 1.1/1.4 MB 1.1 MB/s eta 0:00:01
#    ------------------------------ --------- 1.1/1.4 MB 1.1 MB/s eta 0:00:01
#    ------------------------------ --------- 1.1/1.4 MB 1.1 MB/s eta 0:00:01
#    ------------------------------ --------- 1.1/1.4 MB 1.1 MB/s eta 0:00:01
#    ------------------------------- -------- 1.1/1.4 MB 978.2 kB/s eta 0:00:01
#    -------------------------------- ------- 1.2/1.4 MB 969.6 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.2/1.4 MB 999.6 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.3/1.4 MB 986.8 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.3/1.4 MB 986.9 kB/s eta 0:00:01
#    ------------------------------------- -- 1.4/1.4 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 1.4/1.4 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 995.7 kB/s eta 0:00:00
# Installing collected packages: pyclipper, ninja, Shapely, python-bidi, opencv-python-headless, easyocr
# Successfully installed Shapely-2.0.4 easyocr-1.7.1 ninja-1.11.1.1 opencv-python-headless-4.10.0.84 pyclipper-1.3.0.post5 python-bidi-0.4.2
#   WARNING: The script ninja.exe is installed in 'C:\Users\Patrickn\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pybidi.exe is installed in 'C:\Users\Patrickn\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script easyocr.exe is installed in 'C:\Users\Patrickn\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting imutils
#   Using cached imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py): started
#   Building wheel for imutils (setup.py): finished with status 'done'
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25856 sha256=f2d7be30ea676163fa4f5179796eff5992d19539f48ce2a77a680085ec1da2f1
#   Stored in directory: c:\users\patrickn\appdata\local\pip\cache\wheels\4b\a5\2d\4a070a801d3a3d93f033d3ee9728f470f514826e89952df3ea
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import imutils
import easyocr

# %% [markdown]
# 1. Read in Image, Grayscale and Blur

# %%
img = cv2.imread('image1.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))

# %% [markdown]
# 2. Apply filter and find edges for localization

# %%
bfilter = cv2.bilateralFilter(gray, 11, 17, 17) # Noise reduction
edged = cv2.Canny(bfilter, 30, 200) # Edge detection
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))

# %% [markdown]
# 3. Find Contours and Apply Mask

# %%
keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(keypoints)
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

# %%
location = None
for contour in contours:
    approx = cv2.approxPolyDP(contour, 10, True)
    if len(approx) == 4:
        location = approx
        break

# %%
location
# Out:
# array([[[122, 219]],
#
#        [[246, 227]],
#
#        [[252, 200]],
#
#        [[132, 191]]], dtype=int32)

# %%
mask = np.zeros(gray.shape, np.uint8)
new_image = cv2.drawContours(mask, [location], 0,255, -1)
new_image = cv2.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))

# %%
(x,y) = np.where(mask==255)
(x1, y1) = (np.min(x), np.min(y))
(x2, y2) = (np.max(x), np.max(y))
cropped_image = gray[x1:x2+1, y1:y2+1]

# %%
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))
